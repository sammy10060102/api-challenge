# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URLx
query_url = f"{url}appid={weather_api_key}&units={units}&q="
# print(query_url)


response = requests.get(query_url + 'mar del plata').json()
print(response)
# Out:
# {'coord': {'lon': -57.5575, 'lat': -38.0023}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 54.03, 'feels_like': 52.2, 'temp_min': 52.88, 'temp_max': 56.23, 'pressure': 1023, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 3, 'deg': 314, 'gust': 5.99}, 'clouds': {'all': 0}, 'dt': 1625494537, 'sys': {'type': 2, 'id': 264934, 'country': 'AR', 'sunrise': 1625483182, 'sunset': 1625517779}, 'timezone': -10800, 'id': 3430863, 'name': 'Mar del Plata', 'cod': 200}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
from datetime import date

today = date.today()
print("Today's date:", today)

# set up lists to hold reponse info
city_name = []
lat = []
lon = []
temp = []
temp_max = []
humidity = []
cloudiness = []
wind_speed = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    print(f"city in: {city}")
    
    try:
#         get the country, date here and divide into set of 50 cities
        city_name.append(response['name'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])

    except:
        print(f"The cities is not found")
#         print(f"The latitude information received is: {lat}")
#         print(f"The temperature information received is: {temp}")
#        ` print(f"The max temperature information received is: {temp_max}")
#         print(f"The longitude information received is: {lon}")
#         print(f"The humidity information received is: {humidity}")
#         print(f"The cloudiness information received is: {cloudiness}")
#         print(f"The wind speed information received is: {wind_speed}")
        
        pass

# create a data frame from cities, lat, and temp
city_dict = {
    "city": city_name,
    "lat": lat,
    "long": lon,
    "temp": temp,
    "temp_max": temp_max,
    "humidity": humidity,
    "cloudiness": cloudiness,
    "wind speed": wind_speed
}
city_data_df = pd.DataFrame(city_dict)
city_data_df
# Out:
# Today's date: 2021-07-06
# city in: nanortalik
# city in: san jose
# city in: tuatapere
# city in: los llanos de aridane
# city in: sao felix do xingu
# city in: punta arenas
# city in: albany
# city in: ponta do sol
# city in: lyuban
# city in: kapaa
# city in: smithers
# city in: puerto ayora
# city in: kurumkan
# city in: gerede
# city in: nizhneyansk
# The cities is not found
# city in: rikitea
# city in: butaritari
# city in: lebu
# city in: port-gentil
# city in: barrow
# city in: tuktoyaktuk
# city in: aurillac
# city in: esperance
# city in: comodoro rivadavia
# city in: yeppoon
# city in: bengkulu
# city in: zhigansk
# city in: kodiak
# city in: jamestown
# city in: port alfred
# city in: khatanga
# city in: shenjiamen
# city in: berezovka
# city in: atuona
# city in: iquitos
# city in: natal
# city in: san patricio
# city in: huarmey
# city in: tshikapa
# city in: lembeni
# city in: jakar
# city in: santa cruz de la palma
# city in: ushuaia
# city in: opuwo
# city in: busselton
# city in: bluff
# city in: pathein
# city in: barentsburg
# The cities is not found
# city in: cayenne
# city in: qaanaaq
# city in: ust-nera
# city in: klaksvik
# city in: castro
# city in: arona
# city in: vaini
# city in: taolanaro
# The cities is not found
# city in: namibe
# city in: broome
# city in: hithadhoo
# city in: gornopravdinsk
# city in: mount isa
# city in: victoria
# city in: kahului
# city in: kaniama
# city in: codrington
# city in: port elizabeth
# city in: yellowknife
# city in: priiskovyy
# city in: verkh-usugli
# city in: kaitangata
# city in: tilichiki
# city in: saint-philippe
# city in: manokwari
# city in: verkhnevilyuysk
# city in: aklavik
# city in: cidreira
# city in: gat
# city in: bredasdorp
# city in: najran
# city in: bowmore
# city in: jalu
# city in: airai
# city in: lavrentiya
# city in: parola
# city in: ambunti
# city in: attawapiskat
# The cities is not found
# city in: fortuna
# city in: belushya guba
# The cities is not found
# city in: khanu woralaksaburi
# city in: la ronge
# city in: selty
# city in: berlevag
# city in: chokurdakh
# city in: taoudenni
# city in: kieta
# city in: atar
# city in: abu samrah
# city in: ridgecrest
# city in: constantine
# city in: carmen
# city in: cape town
# city in: te anau
# city in: atbasar
# city in: chyhyryn
# city in: portland
# city in: iqaluit
# city in: stekolnyy
# The cities is not found
# city in: kuche
# The cities is not found
# city in: walvis bay
# city in: mar del plata
# city in: dikson
# city in: bethel
# city in: saskylakh
# city in: chuy
# city in: liniere
# The cities is not found
# city in: bahia blanca
# city in: tungkang
# The cities is not found
# city in: touros
# city in: luderitz
# city in: lima
# city in: kamina
# city in: ballina
# city in: angoche
# city in: hobart
# city in: mys shmidta
# The cities is not found
# city in: pevek
# city in: wells
# city in: qaqortoq
# city in: tateyama
# city in: vanimo
# city in: varzob
# city in: iberia
# city in: cabo san lucas
# city in: roald
# city in: ciudad bolivar
# city in: brekstad
# city in: nakamura
# city in: kenora
# city in: cortes
# city in: laguna
# city in: bom jesus
# city in: sicuani
# city in: faanui
# city in: shache
# city in: sampit
# city in: nuuk
# city in: mahebourg
# city in: felidhoo
# The cities is not found
# city in: japura
# city in: batagay-alyta
# city in: ebbs
# city in: kavieng
# city in: katsuura
# city in: joshimath
# city in: mataura
# city in: panzhihua
# city in: clyde river
# city in: radishchevo
# city in: cape coast
# city in: bima
# city in: pervomayskiy
# city in: hobyo
# city in: tumannyy
# The cities is not found
# city in: florianopolis
# city in: nikolskoye
# city in: salalah
# city in: deputatskiy
# city in: east london
# city in: hilo
# city in: wamba
# city in: adre
# city in: arraial do cabo
# city in: illoqqortoormiut
# The cities is not found
# city in: gazojak
# city in: milingimbi
# The cities is not found
# city in: pingliang
# city in: brzeg dolny
# city in: pasighat
# city in: qui nhon
# city in: hermanus
# city in: torbay
# city in: weihe
# city in: bhindar
# city in: komsomolskiy
# city in: muli
# city in: malinovoye ozero
# city in: guerrero negro
# city in: geraldton
# city in: nguru
# city in: ribeira grande
# city in: matara
# city in: muros
# city in: beloha
# city in: leningradskiy
# city in: namie
# city in: ancud
# city in: martaban
# city in: manturovo
# city in: port blair
# city in: sao filipe
# city in: mossendjo
# city in: general roca
# city in: aborlan
# city in: sentyabrskiy
# The cities is not found
# city in: palabuhanratu
# The cities is not found
# city in: pisco
# city in: new norfolk
# city in: sovetskiy
# city in: shimoda
# city in: san quintin
# city in: asfi
# city in: ust-omchug
# city in: ambon
# city in: thompson
# city in: avarua
# city in: provideniya
# city in: phan thiet
# city in: umzimvubu
# The cities is not found
# city in: ust-kan
# city in: karratha
# city in: nikolayevka
# city in: salgueiro
# city in: caconda
# city in: amderma
# The cities is not found
# city in: panama city
# city in: obanazawa
# city in: tuburan
# city in: fare
# city in: bambous virieux
# city in: macaiba
# city in: eregli
# city in: dingle
# city in: huaral
# city in: lompoc
# city in: tasiilaq
# city in: lorengau
# city in: saldanha
# city in: ucluelet
# city in: tadine
# city in: georgetown
# city in: kusa
# city in: lasa
# city in: calabozo
# city in: gharghoda
# city in: new port richey
# city in: sorland
# city in: tautira
# city in: haines junction
# city in: norman wells
# city in: carnarvon
# city in: poyarkovo
# city in: panaba
# city in: lagoa
# city in: kimbe
# city in: havoysund
# city in: necochea
# city in: sulangan
# city in: ahipara
# city in: manaus
# city in: naryan-mar
# city in: suntar
# city in: uppsala
# city in: houma
# city in: gangapur
# city in: pinawa
# city in: northam
# city in: saint george
# city in: kruisfontein
# city in: saryshagan
# The cities is not found
# city in: kresna
# city in: rabo de peixe
# city in: plettenberg bay
# city in: maceio
# city in: beringovskiy
# city in: tsihombe
# The cities is not found
# city in: tabou
# city in: margate
# city in: venado tuerto
# city in: bitung
# city in: adrar
# city in: saint-joseph
# city in: ulladulla
# city in: high level
# city in: sur
# city in: longyearbyen
# city in: arvika
# city in: mullaitivu
# The cities is not found
# city in: isangel
# city in: carballo
# city in: lufilufi
# city in: texarkana
# city in: isabela
# city in: siyabuswa
# city in: masterton
# city in: mamlyutka
# city in: bathsheba
# city in: bilibino
# city in: ilulissat
# city in: hebi
# city in: yar-sale
# city in: three hills
# city in: kouroussa
# city in: baoshan
# city in: batagay
# city in: tansen
# city in: vardo
# city in: hasaki
# city in: rungata
# The cities is not found
# city in: kirakira
# city in: borovichi
# city in: jiujiang
# city in: alyangula
# city in: san cristobal
# city in: port hardy
# city in: grand gaube
# city in: rocha
# city in: tiksi
# city in: roxana
# city in: yatou
# city in: marsh harbour
# city in: bakchar
# city in: hommelvik
# city in: anadyr
# city in: coquimbo
# city in: coihueco
# city in: saint-pierre
# city in: severo-kurilsk
# city in: takoradi
# city in: thunder bay
# city in: pouembout
# city in: bushehr
# city in: cururupu
# city in: meulaboh
# city in: souillac
# city in: izvestkovyy
# city in: kamenka
# city in: labuan
# city in: husavik
# city in: edd
# city in: ixtapa
# city in: evensk
# city in: basoko
# city in: atambua
# city in: vila franca do campo
# city in: ewo
# city in: jijiga
# city in: talnakh
# city in: koror
# city in: po
# The cities is not found
# city in: waipawa
# city in: saint-augustin
# city in: celestun
# city in: progreso
# city in: bayshore gardens
# city in: vasterhaninge
# city in: tabiauea
# The cities is not found
# city in: maragogi
# city in: pundaguitan
# city in: sabang
# city in: forio
# city in: kisoro
# city in: grand river south east
# The cities is not found
# city in: pontalina
# city in: mandurah
# city in: laguna de perlas
# city in: nortelandia
# city in: ninghai
# city in: zlobin
# city in: vredendal
# city in: cherskiy
# city in: talaya
# city in: bay saint louis
# city in: sao joao da barra
# city in: nhulunbuy
# city in: shemonaikha
# city in: yantzaza
# city in: abalak
# city in: petrove
# city in: wadi maliz
# city in: mildura
# city in: kitakyushu
# city in: jining
# city in: cockburn town
# city in: verkhneyarkeyevo
# city in: morehead
# city in: la reforma
# city in: along
# city in: ituni
# The cities is not found
# city in: olafsvik
# city in: nyurba
# city in: ngunguru
# city in: umea
# city in: alice springs
# city in: hovd
# city in: kununurra
# city in: manavalakurichi
# city in: marawi
# city in: kita
# city in: kijang
# city in: egvekinot
# city in: samusu
# The cities is not found
# city in: samalaeulu
# The cities is not found
# city in: arosa
# city in: constitucion
# city in: pangnirtung
# city in: chapais
# city in: abbeville
# city in: poum
# city in: pilar
# city in: port pirie
# city in: santa rosalia
# city in: goure
# city in: imbituba
# city in: mbengwi
# city in: nkoteng
# city in: igrim
# city in: suicheng
# city in: anjozorobe
# city in: college
# city in: mount gambier
# city in: alta floresta
# city in: ossora
# city in: batsfjord
# city in: aleksandrovsk-sakhalinskiy
# city in: palembang
# city in: onega
# city in: barranca
# city in: vaitupu
# The cities is not found
# city in: erenhot
# city in: tarko-sale
# city in: saint-esteve
# city in: sergach
# city in: naftah
# The cities is not found
# city in: changji
# city in: stornoway
# city in: souris
# city in: anapskaya
# city in: kumluca
# city in: paradwip
# The cities is not found
# city in: sawakin
# city in: senj
# city in: surgut
# city in: podgornoye
# city in: bismil
# city in: praia da vitoria
# city in: eskisehir
# city in: contai
# city in: alofi
# city in: ocolis
# The cities is not found
# city in: catuday
# city in: neuquen
# city in: honiara
# city in: naze
# city in: rawson
# city in: novopokrovka
# city in: kazalinsk
# The cities is not found
# city in: fort nelson
# city in: mpulungu
# city in: tigil
# city in: xining
# city in: tessalit
# city in: richards bay
# city in: sibolga
# city in: bonaventure
# city in: jiayuguan
# city in: temerloh
# city in: fort-shevchenko
# city in: hoquiam
# city in: cozumel
# city in: dvorichna
# city in: price
# city in: bandar
# city in: dali
# city in: manicore
# city in: sioux lookout
# city in: denpasar
# city in: hay river
# city in: lucapa
# city in: kudahuvadhoo
# city in: vila velha
# city in: viedma
# city in: alihe
# city in: eyl
# city in: makasar
# city in: safaqis
# The cities is not found
# city in: port macquarie
# city in: gwembe
# city in: kargasok
# city in: marang
# city in: paka
# city in: chernyanka
# city in: gonen
# city in: upington
# city in: veraval
# city in: umm kaddadah
# city in: angra dos reis
# city in: inderborskiy
# The cities is not found
# city in: hamilton
# city in: samarai
# city in: estevan
# city in: kandi
# city in: ingham
# city in: borogontsy
# city in: torrington
# city in: belaya gora
# city in: chumikan
# city in: alberton
# city in: dharchula
# city in: ponyri
# city in: buala
# city in: sitka
# city in: saleaula
# The cities is not found
# city in: korla
# city in: gbongan
# city in: grand baie
# city in: spearfish
# city in: narsaq
# city in: altay
# city in: gunjur
# city in: rundu
# city in: tangping
# city in: tezu
# city in: vastervik
# The cities is not found
# city in: kenitra
# city in: chagda
# The cities is not found
# city in: anamur
# city in: upernavik
# city in: vradiyivka
# city in: dauphin
# city in: berdigestyakh
# city in: bantry
# city in: trinidad
# city in: coulihaut
# The cities is not found
# city in: burkhala
# The cities is not found
# city in: bandarbeyla
# city in: beterou
# city in: machida
# city in: quang ngai
# city in: santo antonio do sudoeste
# city in: cloppenburg
# city in: mundra
# city in: mount hagen
# city in: khokhryaki
# city in: barra patuca
# city in: slobodskoy
# city in: coihaique
# city in: keffi
# city in: cam ranh
# city in: piacabucu
# city in: santa ana
# city in: oktyabrskiy
# city in: verkhniy mamon
# city in: chau doc
# city in: maridi
# city in: hoa binh
# city in: maua
# city in: labuhan
# city in: camacha
# city in: feni
# city in: bontang
# city in: bulungu
# city in: buin
# city in: hedaru
# city in: abu dhabi
# city in: lolua
# The cities is not found
# city in: kiunga
# city in: sumbawa
# The cities is not found
# city in: lukovetskiy
# city in: ostrovnoy
# city in: luanda
# city in: sinkat
# The cities is not found
# city in: kapoeta
# city in: sal rei
# city in: oranjemund
# city in: kavaratti
# city in: sedelnikovo
# The cities is not found
# city in: karamea
# The cities is not found
# city in: duldurga
# city in: nizhniy tagil-39
# The cities is not found
# city in: ulaanbaatar
# city in: lakhimpur
# city in: inhambane
# city in: makakilo city
# city in: fukue
# city in: seymchan
# city in: navapur
# The cities is not found
# city in: vestmannaeyjar
# city in: sisimiut
# city in: novoagansk
# city in: nanzhang
# city in: xuddur
# city in: rancho cucamonga
# city in: moroto
# city in: kutum
# city in: varadero
# city in: kuloy
# city in: rio grande
# city in: bojnurd
# city in: windsor
# city in: palmares do sul
# city in: khorramshahr
# city in: moose factory
# city in: sterling
# city in: azimur
# The cities is not found
# city in: ilanskiy
# city in: puerto quijarro
#                       city      lat      long    temp  temp_max  humidity  \
# 0               Nanortalik  60.1432  -45.2371   42.84     42.84        96
# 1                 San Jose  37.3394 -121.8950   58.48     62.46        84
# 2                Tuatapere -46.1333  167.6833   49.96     49.96        85
# 3    Los Llanos de Aridane  28.6585  -17.9182   72.12     73.15        77
# 4       São Félix do Xingu  -6.6447  -51.9950   87.80     87.80        33
# ..                     ...      ...       ...     ...       ...       ...
# 553           Khorramshahr  30.4397   48.1664  114.76    114.76        12
# 554          Moose Factory  51.2585  -80.6094   80.58     80.60        65
# 555               Sterling  39.0062  -77.4286   80.58     84.49        67
# 556               Ilanskiy  56.2358   96.0650   70.59     70.59        74
# 557        Puerto Quijarro -17.7833  -57.7667   84.81     84.81        21
#
#      cloudiness  wind speed
# 0           100        5.82
# 1            90        1.99
# 2           100        5.01
# 3            20       17.27
# 4             7        5.84
# ..          ...         ...
# 553           0       13.80
# 554           1       10.36
# 555          75        1.01
# 556          32        0.63
# 557           0        4.03
#
# [558 rows x 8 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
